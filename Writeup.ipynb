# %% [markdown]
# # **Traffic Sign Recognition**
#
# ## Writeup
#
# ### You can use this file as a template for your writeup if you want to submit it as a markdown file, but feel free to use some other method and submit a pdf if you prefer.
#
# ---
#
# **Build a Traffic Sign Recognition Project**
#
# The goals / steps of this project are the following:
# * Load the data set (see below for links to the project data set)
# * Explore, summarize and visualize the data set
# * Design, train and test a model architecture
# * Use the model to make predictions on new images
# * Analyze the softmax probabilities of the new images
# * Summarize the results with a written report
#
#
# [//]: # (Image References)
#
# [image1]: ./result-images/barplot.png "Visulization"
# [image2]: ./result-images/grayscale-images.png "Grayscaling"
# [image3]: ./result-images/augmented-images.png "Random Noise"
# [image4]: ./web-test-data/test1.png "Traffic Sign 1"
# [image5]: ./web-test-data/test2.png "Traffic Sign 2"
# [image6]: ./web-test-data/test3.png "Traffic Sign 3"
# [image7]: ./web-test-data/test4.png "Traffic Sign 4"
# [image8]: ./web-test-data/test5.png "Traffic Sign 5"
# [image9]: ./web-test-data/test6.png "Traffic Sign 6"
# [image10]: ./result-images/Topk-images.png "Top 5 Probabilities"
# [image11]: ./result-images/FeatureMap1.png "FeatureMap 1"
# [image12]: ./result-images/FeatureMap2.png "FeatureMap 2"
# [image13]: ./result-images/FeatureMap3.png "FeatureMap 3"
# [image14]: ./result-images/FeatureMap4.png "FeatureMap 4"
# [image15]: ./result-images/FeatureMap5.png "FeatureMap 5"
# [image16]: ./result-images/FeatureMap6.png "FeatureMap 6"
#
# ## Rubric Points
# ### Here I will consider the [rubric points](https://review.udacity.com/#!/rubrics/481/view) individually and describe how I addressed each point in my implementation.
#
# ---
# ### Writeup / README
#
# #### 1. Provide a Writeup / README that includes all the rubric points and how you addressed each one. You can submit your writeup as markdown or pdf. You can use this template as a guide for writing the report. The submission includes the project code.
#
# You're reading it! and here is a link to my [project code](https://github.com/xiaohuieddie/Traffic-signs/blob/master/Traffic_Sign_Classifier.ipynb)
#
#
# ### Data Set Summary & Exploration
#
# #### 1. Provide a basic summary of the data set. In the code, the analysis should be done using python, numpy and/or pandas methods rather than hardcoding results manually.
#
# I used the Numpy library to calculate summary statistics of the traffic
# signs data set:
#
# * The size of training set is 34799
# * The size of the validation set is 4410
# * The size of test set is 12630
# * The shape of a traffic sign image is (32,32,3)
# * The number of unique classes/labels in the data set is 43
#
# #### 2. Include an exploratory visualization of the dataset.
#
# Here is an exploratory visualization of the data set. It is a bar chart showing how the data:
# ![alt text][image1]
#
# ### Design and Test a Model Architecture
#
# #### 1. Describe how you preprocessed the image data. What techniques were chosen and why did you choose these techniques? Consider including images showing the output of each preprocessing technique. Pre-processing refers to techniques such as converting to grayscale, normalization, etc. (OPTIONAL: As described in the "Stand Out Suggestions" part of the rubric, if you generated additional data for training, describe why you decided to generate additional data, how you generated the data, and provide example images of the additional data. Then describe the characteristics of the augmented training set like number of images in the set, number of images for each class, etc.)
#
# As a first step, I decided to convert the images to grayscale because it can get rid of the noise information caused by different color space. Grayscale simplifies the algorithm and reduces computational requirements due to one dimensional space. Indeed, color may be of limited benefit in many applications and introducing unnecessary information could increase the amount of training data required to achieve good performance.
#
# Here is an example of a traffic sign image before and after grayscaling.
#
# ![alt text][image2]
#
# As a last step, I normalized the image data because if we didn't scale our input training vectors, the ranges of our distributions of feature values would likely be different for each feature.We'd like in the process of backpropagation for each feature to have a similar range so that our gradients don't go out of control. Without normalization, it is is non-ideal as we might find ourselves in a oscillating (unable to center onto a better maxima in cost(weights) space) state or in a slow moving (traveling too slow to get to a better maxima) state.
#
# I decided to generate additional data because more data will reduce the effect of overfitting and improve the prediction accuracy of the model.
#
# To add more data to the the data set, Initially I used the following techniques:
# * Brightness Adjustment
# * Rotation
# * Translation
# * Shear
#
# However, I just got a kind of low validation accuracy aroung 80%-90% since the more changes in the image dataset the far from generalization as I have fewer data to support that kind of spread in data augmentation. Followed the advise from the Forum mentor, I just did brightness adjust ment and rotation for my final testing, which gave me pretty impressively good result of validation accuracy and training accuracy.
#
# Here is an example of an original image and an augmented(Brightness&Rotation) image:
#
# ![alt text][image3]
#
# The difference between the original data set and the augmented data set is the following:
#
# |                  |Original data set |Augmented data set      		    |
# |:----------------:|:----------------:|:-------------------------------:|
# | Number of images | 34799  	      | 208794                          |
#
#
#
# #### 2. Describe what your final model architecture looks like including model type, layers, layer sizes, connectivity, etc.) Consider including a diagram and/or table describing the final model.
#
# My final model consisted of the following layers:
#
# | Layer         		|     Description	        					|
# |:---------------------:|:---------------------------------------------:|
# | Input         		| 64x64x3 Pre-processed(Grayscale&Normalized) image   							|
# | Convolution 5x5     	| 5x5 stride, Valid padding, outputs 28x28x6 	|
# | RELU					|												|
# | Max pooling	      	| 2x2 stride, Valid padding, outputs 14x14x6 	|
# | Convolution 5x5	    | 5x5 stride, Valid padding, outputs 10x10x16   |
# | RELU					|												|
# | Max pooling	      	| 2x2 stride, Valid padding, outputs 5x5x16 	|
# | Fully connected		| Output 120        							|
# | RELU					|												|
# | Fully connected		| Output 84        						    	|
# | RELU					|											 	|
# | Fully connected		| Output 43        						    	|
# | softmax				|											 	|
#
#
#
# #### 3. Describe how you trained your model. The discussion can include the type of optimizer, the batch size, number of epochs and any hyperparameters such as learning rate.
#
# To train the model, the setting I used is following:
#
# |     |   |
# |-----|---|
# |Optimizer|AdamOptimizer|
# |Batch size|128|
# |EPOCHS| 30|
# |Learning rate| 0.002|
# |Dropout rate| 0.5|
#
#
# #### 4. Describe the approach taken for finding a solution and getting the validation set accuracy to be at least 0.93. Include in the discussion the results on the training, validation and test sets and where in the code these were calculated. Your approach may have been an iterative process, in which case, outline the steps you took to get to the final solution and why you chose those steps. Perhaps your solution involved an already well known implementation or architecture. In this case, discuss why you think the architecture is suitable for the current problem.
#
# My final model results were:
# * training set accuracy of 0.995
# * validation set accuracy of 0.965
# * test set accuracy of 0.947
#
# If an iterative approach was chosen:
# * What was the first architecture that was tried and why was it chosen?
#
# The first architecture is the same as LeNet because it was kind of shallow ConNet and it is very easy to understand and implement. From the LeNet Solution, this architecture also did a good job in the MNIST data set.
#
# * What were some problems with the initial architecture?
#
# It caused the problem of overfitting and low validation accuracy.
#
# * How was the architecture adjusted and why was it adjusted? Typical adjustments could include choosing a different model architecture, adding or taking away layers (pooling, dropout, convolution, etc), using an activation function or changing the activation function. One common justification for adjusting an architecture would be due to overfitting or underfitting. A high accuracy on the training set but low accuracy on the validation set indicates over fitting; a low accuracy on both sets indicates under fitting.
#
# The only thing I adjusted is to add dropout for first two fully connected layer, which contributes to reducing the effect of the overfitting.
#
# * Which parameters were tuned? How were they adjusted and why?
#
# Learning rate: Initially the learning rate I chosen is 0.001 or even smaller, but it gave me low Training & Validation accuracy within 30 Epochs. I increase the learning rate since the model is learning too slow.
#
# Dropout: Initially I used keep_prob=0.8-1 but the larger overfitting still exists, then I tried 0.5, which improve the result. Additionally, I also tried pretty small keep_prob=0.3, it gave me a very low accuracy since it will lose most of the featured learned.
#
# * What are some of the important design choices and why were they chosen? For example, why might a convolution layer work well with this problem? How might a dropout layer help with creating a successful model?
# The data augmentation and pre-process is an important part we need to put more concentration on. Appropriate data augmentation and pre-process not only can make the performance of the model better, it can also make a great impact on reducing the overfitting. I tried only converting the dataset to grayscale but not normalized them, which would decrease both training and validation accuracy by 10% due to large variance of the images. In addition, augmentating the data properly also has a big influence on the performance. Instead of implemented all the triks such as shearing, rotation and translation, I just implemented one of them, which improve the performance of my model by over 5%.
#
# Dropout definitely plays a key role in improving the effect of overfitting and reducing the computational parameter. Through experimental trial, normally dropout rate 0.4-0.6 works pretty nice to solve the problem of overfitting and also keep the high accuracy.
#
#
# If a well known architecture was chosen:
# * What architecture was chosen?
# * Why did you believe it would be relevant to the traffic sign application?
# * How does the final model's accuracy on the training, validation and test set provide evidence that the model is working well?
#
#
# ### Test a Model on New Images
#
# #### 1. Choose five German traffic signs found on the web and provide them in the report. For each image, discuss what quality or qualities might be difficult to classify.
#
# Here are six German traffic signs that I found on the web:
#
# ![alt text][image4] ![alt text][image5] ![alt text][image6]
# ![alt text][image7] ![alt text][image8] ![alt text][image9]
#
# All the image should be easy to be classified since the images are very imilar to the training image except the third one(Stop Traffic sign).The shape would be difficult to detected perfectly for the first, fourth and fifth images. For the second image, the color contrast might be the key point to classify. Additionally, the key part is to get to know yield letter and triangle shape for the last one. The image of Stop sign is a relatively small image and it is very different from the Stop sign as shown in training set.
#
# #### 2. Discuss the model's predictions on these new traffic signs and compare the results to predicting on the test set. At a minimum, discuss what the predictions were, the accuracy on these new predictions, and compare the accuracy to the accuracy on the test set (OPTIONAL: Discuss the results in more detail as described in the "Stand Out Suggestions" part of the rubric).
#
# Here are the results of the prediction:
#
# | Image			        |     Prediction	        					|
# |:---------------------:|:---------------------------------------------:|
# | Go straight or right    	| Go straight or right  					|
# | Traffic signals     			| Traffic signals 						|
# | Stop sign					| speed limit(50km/h)						|
# | wild animals crossing	      		| wild animals crossing				|
# | Slippery Road			| Slippery Road      							|
# | Yield		| Yield     							|
#
# The model was able to correctly guess 5 of the 6 traffic signs, which gives an accuracy of 83.33%. However this accuracy can't indicate the real teat accuracy due to such small number of data set. Comparing the accuracy with that of entire test data set, the model is working fine to predict the image shown on the training set. But it got difficulties in predicting unknown image such as the 'Stop' sign.
#
# #### 3. Describe how certain the model is when predicting on each of the five new images by looking at the softmax probabilities for each prediction. Provide the top 5 softmax probabilities for each image along with the sign type of each probability. (OPTIONAL: as described in the "Stand Out Suggestions" part of the rubric, visualizations can also be provided such as bar charts)
#
# The code for making predictions on my final model is located in the 11th cell of the Ipython notebook.
#
# The exact distribution of probability for top 5 classes are shown in the bar plot below:
# ![alt text][image10]
#
# For the first image, the model is so sure that this is a Go straight or right sign (probability of 0.9998), and the image does contain a Go straight or right sign. The top five soft max probabilities were
#
# | Probability         	|     Prediction	        					|
# |:---------------------:|:---------------------------------------------:|
# | .9998         		| Go straight or right  						|
# | .0002     			| Ahead only 									|
# | 5.1575e-7				| Priority road									|
# | 4.6373e-7	   			| Turn left ahead					 			|
# | 4.4594e-7			    | End of all speed and passing limits    		|
#
#
# For the second image, the model is so sure that this is a Traffic signal (probability of 0.5934), and the image does contain a Traffic signal sign. The top five soft max probabilities were
#
# | Probability         	|     Prediction	        					|
# |:---------------------:|:---------------------------------------------:|
# | .5934         		| Traffic signal  						        |
# | .2415     			| General caution 								|
# | .1214			    	| Pedestrians						            |
# | .0388	   			    | Road narrows on the right					 	|
# | .00188			    | Right-of-way at the next intersection   		|
#
# For the third image, the model is relatively sure that this is a Speed limit (50km/h) (probability of 0.3402), and the images from top five images does contain a Stop signal sign( probability of 0.0825). The top five soft max probabilities were
#
# | Probability         	|     Prediction	        					|
# |:---------------------:|:---------------------------------------------:|
# | .3402         		| Speed limit (50km/h)  						|
# | .2171     			| Yield 						         		|
# | .0825			    	| Stop						                    |
# | .0654   			    | Keep right			                    	|
# | .0508			        | Speed limit (100km/h)  		                |
#
# For the fourth image, the model is so sure that this is a Wild animals crossing signal (probability of 0.9321), and the image does contain a Wild animals crossing signal sign. The top five soft max probabilities were
#
# | Probability         	|     Prediction	        					|
# |:---------------------:|:---------------------------------------------:|
# | .9321         		| Wild animals crossing 						|
# | .0679     			| Slippery road				     				|
# | 5.7937e-05			| Double curve						            |
# | 1.5817e-06	   	    | Road work				                    	|
# | 7.3041e-07			| Bicycles crossing  	                        |
#
# For the fifth image, the model is so sure that this is a Slippery road signal (probability of 0.9999), and the image does contain a Slippery road signal sign. The top five soft max probabilities were
#
# | Probability         	|     Prediction	        					|
# |:---------------------:|:---------------------------------------------:|
# | .9999        	    	| Slippery road 				  		        |
# | 3.8463e-05         	| No passing for vehicles over 3.5 metric tons	|
# | 3.1088e-06		    | Dangerous curve to the right					|
# | 1.3013e-06	   	    | Bicycles crossing				        	 	|
# | 2.5312e-07			| Beware of ice/snow 	                    	|
#
# For the sixth image, the model is so sure that this is a Yield signal (probability of 1), and the image does contain a Yield sign. The top five soft max probabilities were
#
# | Probability         	|     Prediction	        					|
# |:---------------------:|:---------------------------------------------:|
# | 1              		| Yield 						                |
# | 2.9485e-28     		| Priority road						     		|
# | 2.4451e-30		    | Keep left						                |
# | 8.4915e-31   		    | Stop				                        	|
# | 1.1631e-33		    | Ahead only  		                            |
#
# ### (Optional) Visualizing the Neural Network (See Step 4 of the Ipython notebook for more details)
# #### 1. Discuss the visual output of your trained network's feature maps. What characteristics did the neural network use to make classifications?
# ![alt text][image4] ![alt text][image11] ![alt text][image12]
# By plotting the feature maps from the first and second convolutional layer, we can conclude that the first layer will detect most of the edges of the image and the second layer will focus more on the small zone of the image.
